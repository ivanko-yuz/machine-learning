# %% [markdown]
# # Diabetes Prediction (with Model Reload)

# %% [markdown]
# Import some basic libraries.
# * Pandas - provided data frames
# * matplotlib.pyplot - plotting support
#
# Use Magic %matplotlib to display graphics inline instead of in a popup window.

# %%
# Install a pip package in the current Jupyter kernel
# import sys
# !{sys.executable} -m pip install numpy


import pandas as pd                 # pandas is a dataframe library
import matplotlib.pyplot as plt     # matplotlib.pyplot plots data
import numpy as np                  # numpy provides N-dim object support
import sklearn

# %matplotlib inline

# %% [markdown]
# ## Load and review data

# %%
df = pd.read_csv("./data/pima-data.csv")

# %%
df.shape
# Out:
# (768, 10)

# %%
df.head(5)
# Out:
#    num_preg  glucose_conc  diastolic_bp  thickness  insulin   bmi  diab_pred  \
# 0         6           148            72         35        0  33.6      0.627
# 1         1            85            66         29        0  26.6      0.351
# 2         8           183            64          0        0  23.3      0.672
# 3         1            89            66         23       94  28.1      0.167
# 4         0           137            40         35      168  43.1      2.288
#
#    age    skin  diabetes
# 0   50  1.3790      True
# 1   31  1.1426     False
# 2   32  0.0000      True
# 3   21  0.9062     False
# 4   33  1.3790      True

# %%
df.tail(5)
# Out:
#      num_preg  glucose_conc  diastolic_bp  thickness  insulin   bmi  \
# 763        10           101            76         48      180  32.9
# 764         2           122            70         27        0  36.8
# 765         5           121            72         23      112  26.2
# 766         1           126            60          0        0  30.1
# 767         1            93            70         31        0  30.4
#
#      diab_pred  age    skin  diabetes
# 763      0.171   63  1.8912     False
# 764      0.340   27  1.0638     False
# 765      0.245   30  0.9062     False
# 766      0.349   47  0.0000      True
# 767      0.315   23  1.2214     False

# %% [markdown]
# ### Definition of features
# From the metadata on the data source we have the following definition of the features.
#
# | Feature  | Description | Comments |
# |--------------|-------------|--------|
# | num_preg     | number of pregnancies         |
# | glucose_conc | Plasma glucose concentration a 2 hours in an oral glucose tolerance test         |
# | diastolic_bp | Diastolic blood pressure (mm Hg) |
# | thickness | Triceps skin fold thickness (mm) |
# |insulin | 2-Hour serum insulin (mu U/ml) |
# | bmi |  Body mass index (weight in kg/(height in m)^2) |
# | diab_pred |  Diabetes pedigree function |
# | Age (years) | Age (years)|
# | skin | ???? | What is this? |
# | diabetes | Class variable (1=True, 0=False) |  Why is our data boolean (True/False)? |

# %% [markdown]
# ## Check for null values

# %%
df.isnull().values.any()
# Out:
# False

# %% [markdown]
# ### Correlated Feature Check

# %% [markdown]
# Helper function that displays correlation by color.  Red is most correlated, Blue least.

# %%
def plot_corr(df, size=11):
    """
    Function plots a graphical correlation matrix for each pair of columns in the dataframe.

    Input:
        df: pandas DataFrame
        size: vertical and horizontal size of the plot

    Displays:
        matrix of correlation between columns.  Blue-cyan-yellow-red-darkred => less to more correlated
                                                0 ------------------>  1
                                                Expect a darkred line running from top left to bottom right
    """

    corr = df.corr()    # data frame correlation function
    fig, ax = plt.subplots(figsize=(size, size))
    ax.matshow(corr)   # color code the rectangles by correlation value
    plt.xticks(range(len(corr.columns)), corr.columns)  # draw x tick marks
    plt.yticks(range(len(corr.columns)), corr.columns)  # draw y tick marks

# %%
plot_corr(df)

# %%
df.corr()
# Out:
#               num_preg  glucose_conc  diastolic_bp  thickness   insulin  \
# num_preg      1.000000      0.129459      0.141282  -0.081672 -0.073535
# glucose_conc  0.129459      1.000000      0.152590   0.057328  0.331357
# diastolic_bp  0.141282      0.152590      1.000000   0.207371  0.088933
# thickness    -0.081672      0.057328      0.207371   1.000000  0.436783
# insulin      -0.073535      0.331357      0.088933   0.436783  1.000000
# bmi           0.017683      0.221071      0.281805   0.392573  0.197859
# diab_pred    -0.033523      0.137337      0.041265   0.183928  0.185071
# age           0.544341      0.263514      0.239528  -0.113970 -0.042163
# skin         -0.081672      0.057328      0.207371   1.000000  0.436783
# diabetes      0.221898      0.466581      0.065068   0.074752  0.130548
#
#                    bmi  diab_pred       age      skin  diabetes
# num_preg      0.017683  -0.033523  0.544341 -0.081672  0.221898
# ...

# %%
df.head(5)
# Out:
#    num_preg  glucose_conc  diastolic_bp  thickness  insulin   bmi  diab_pred  \
# 0         6           148            72         35        0  33.6      0.627
# 1         1            85            66         29        0  26.6      0.351
# 2         8           183            64          0        0  23.3      0.672
# 3         1            89            66         23       94  28.1      0.167
# 4         0           137            40         35      168  43.1      2.288
#
#    age    skin  diabetes
# 0   50  1.3790      True
# 1   31  1.1426     False
# 2   32  0.0000      True
# 3   21  0.9062     False
# 4   33  1.3790      True

# %%
del df["skin"]

# %%
df.head(5)
# Out:
#    num_preg  glucose_conc  diastolic_bp  thickness  insulin   bmi  diab_pred  \
# 0         6           148            72         35        0  33.6      0.627
# 1         1            85            66         29        0  26.6      0.351
# 2         8           183            64          0        0  23.3      0.672
# 3         1            89            66         23       94  28.1      0.167
# 4         0           137            40         35      168  43.1      2.288
#
#    age  diabetes
# 0   50      True
# 1   31     False
# 2   32      True
# 3   21     False
# 4   33      True

# %%
plot_corr(df)

# %% [markdown]
# ## Check data types

# %%
df.head(5)
# Out:
#    num_preg  glucose_conc  diastolic_bp  thickness  insulin   bmi  diab_pred  \
# 0         6           148            72         35        0  33.6      0.627
# 1         1            85            66         29        0  26.6      0.351
# 2         8           183            64          0        0  23.3      0.672
# 3         1            89            66         23       94  28.1      0.167
# 4         0           137            40         35      168  43.1      2.288
#
#    age  diabetes
# 0   50      True
# 1   31     False
# 2   32      True
# 3   21     False
# 4   33      True

# %% [markdown]
# Change True to 1, and False to 0

# %%
diabetes_map = {True : 1, False : 0}

# %%
df["diabetes"] = df["diabetes"].map(diabetes_map)

# %%
df.head(5)
# Out:
#    num_preg  glucose_conc  diastolic_bp  thickness  insulin   bmi  diab_pred  \
# 0         6           148            72         35        0  33.6      0.627
# 1         1            85            66         29        0  26.6      0.351
# 2         8           183            64          0        0  23.3      0.672
# 3         1            89            66         23       94  28.1      0.167
# 4         0           137            40         35      168  43.1      2.288
#
#    age  diabetes
# 0   50         1
# 1   31         0
# 2   32         1
# 3   21         0
# 4   33         1

# %% [markdown]
# ## Check *true/false* ration

# %%
num_obs = len(df)

num_true = len(df.loc[df["diabetes"] == True])
num_false = len(df.loc[df["diabetes"] == False])

print("Number of True cases:  {0} ({1:2.2f}%)".format(num_true, (num_true/num_obs) * 100))
print("Number of False cases: {0} ({1:2.2f}%)".format(num_false, (num_false/num_obs) * 100))
# Out:
# Number of True cases:  268 (34.90%)
# Number of False cases: 500 (65.10%)

# %% [markdown]
# Type of learnings are:
#  - supervised
#  - unsupervised (claster)
#
# Prediction model means <b>supervised machine learning</b>.
#
# Types of results are:
#  - regression (continues values) change in a feature -> change result
#  - classification (discrete values) change in a feature may or may not change result
#
# So we need binary <b>classification</b>
#
# In the end lest look in 3 algorythms:
#  - Naive Basis (based on likelihood and probability)
#  - Logistic Regression
#  - Decision Tree (requires a lot value to determined nodes data)

# %% [markdown]
# Good distribution of true and false cases.  No special work needed.

# %% [markdown]
# ### Spliting the data
#
# 70% for training, 30% for testing

# %%
#from sklearn.cross_validation import train_test_split
from sklearn.model_selection import train_test_split

feature_col_names = ['num_preg', 'glucose_conc', 'diastolic_bp', 'thickness', 'insulin', 'bmi', 'diab_pred', 'age']
predicted_class_names = ['diabetes']

X = df[feature_col_names].values     # predictor feature columns (8 X m)
y = df[predicted_class_names].values # predicted class (1=true, 0=false) column (1 X m)

split_test_size = 0.30

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=split_test_size, random_state=42) 
                            # test_size = 0.3 is 30%, 42 is the answer to everything (rerun will be identical)

# %% [markdown]
# We check to ensure we have the the desired 70% train, 30% test split of the data

# %%
print("{0:0.2f}% in training set".format((len(X_train)/len(df.index)) * 100))
print("{0:0.2f}% in test set".format((len(X_test)/len(df.index)) * 100))
# Out:
# 69.92% in training set
# 30.08% in test set

# %% [markdown]
# #### Verifying predicted value was split correctly

# %%
print("Original True  : {0} ({1:0.2f}%)".format(len(df.loc[df['diabetes'] == 1]), (len(df.loc[df['diabetes'] == 1])/len(df.index)) * 100.0))
print("Original False : {0} ({1:0.2f}%)".format(len(df.loc[df['diabetes'] == 0]), (len(df.loc[df['diabetes'] == 0])/len(df.index)) * 100.0))
print("")
print("Training True  : {0} ({1:0.2f}%)".format(len(y_train[y_train[:] == 1]), (len(y_train[y_train[:] == 1])/len(y_train) * 100.0)))
print("Training False : {0} ({1:0.2f}%)".format(len(y_train[y_train[:] == 0]), (len(y_train[y_train[:] == 0])/len(y_train) * 100.0)))
print("")
print("Test True      : {0} ({1:0.2f}%)".format(len(y_test[y_test[:] == 1]), (len(y_test[y_test[:] == 1])/len(y_test) * 100.0)))
print("Test False     : {0} ({1:0.2f}%)".format(len(y_test[y_test[:] == 0]), (len(y_test[y_test[:] == 0])/len(y_test) * 100.0)))
# Out:
# Original True  : 268 (34.90%)
# Original False : 500 (65.10%)
#
# Training True  : 188 (35.01%)
# Training False : 349 (64.99%)
#
# Test True      : 80 (34.63%)
# Test False     : 151 (65.37%)

# %% [markdown]
# ### Post-split Data Preparation

# %% [markdown]
# #### Hidden Missing Values

# %%
df.head()
# Out:
#    num_preg  glucose_conc  diastolic_bp  thickness  insulin   bmi  diab_pred  \
# 0         6           148            72         35        0  33.6      0.627
# 1         1            85            66         29        0  26.6      0.351
# 2         8           183            64          0        0  23.3      0.672
# 3         1            89            66         23       94  28.1      0.167
# 4         0           137            40         35      168  43.1      2.288
#
#    age  diabetes
# 0   50         1
# 1   31         0
# 2   32         1
# 3   21         0
# 4   33         1

# %% [markdown]
# Are these 0 values possible?
#
# How many rows have have unexpected 0 values?

# %%
print("# rows in dataframe {0}".format(len(df)))
print("# rows missing glucose_conc: {0}".format(len(df.loc[df['glucose_conc'] == 0])))
print("# rows missing diastolic_bp: {0}".format(len(df.loc[df['diastolic_bp'] == 0])))
print("# rows missing thickness: {0}".format(len(df.loc[df['thickness'] == 0])))
print("# rows missing insulin: {0}".format(len(df.loc[df['insulin'] == 0])))
print("# rows missing bmi: {0}".format(len(df.loc[df['bmi'] == 0])))
print("# rows missing diab_pred: {0}".format(len(df.loc[df['diab_pred'] == 0])))
print("# rows missing age: {0}".format(len(df.loc[df['age'] == 0])))
# Out:
# # rows in dataframe 768
# # rows missing glucose_conc: 5
# # rows missing diastolic_bp: 35
# # rows missing thickness: 227
# # rows missing insulin: 374
# # rows missing bmi: 11
# # rows missing diab_pred: 0
# # rows missing age: 0

# %% [markdown]
# #### Impute with the mean

# %%
# NEED CALLOUT MENTION CHANGE TO SIMPLEIMPUTER
#from sklearn.preprocessing import Imputer
from sklearn.impute import SimpleImputer
#Impute with mean all 0 readings
#fill_0 = Imputer(missing_values=0, strategy="mean", axis=0)
fill_0 = SimpleImputer(missing_values=0, strategy="mean")
X_train = fill_0.fit_transform(X_train)
X_test = fill_0.fit_transform(X_test)

# %% [markdown]
# ## Training Initial Algorithm - Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB

# create Gaussian Naive Bayes model object and train it with the data
nb_model = GaussianNB()

nb_model.fit(X_train, y_train.ravel())
# Out:
# GaussianNB()

# %%
# predict values using the training data
nb_predict_train = nb_model.predict(X_train)

# import the performance metrics library
from sklearn import metrics

# Accuracy
print("Accuracy: {0:.4f}".format(metrics.accuracy_score(y_train, nb_predict_train)))
# Out:
# Accuracy: 0.7542

# %% [markdown]
# ### Performance on Testing Data

# %%
# predict values using the training data
nb_predict_test = nb_model.predict(X_test)

# import the performance metrics library
from sklearn import metrics

# Accuracy
print("Accuracy: {0:.4f}".format(metrics.accuracy_score(y_test, nb_predict_test)))
# Out:
# Accuracy: 0.7359

# %% [markdown]
# ## Metrics

# %%
print("Confusion Matrix")
print("{0}".format(metrics.confusion_matrix(y_test, nb_predict_test)))
print("")

print("Classification Report")
print(metrics.classification_report(y_test, nb_predict_test))
# Out:
# Confusion Matrix
# [[118  33]
#  [ 28  52]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.81      0.78      0.79       151
#            1       0.61      0.65      0.63        80
#
#     accuracy                           0.74       231
#    macro avg       0.71      0.72      0.71       231
# weighted avg       0.74      0.74      0.74       231

# %% [markdown]
# Confusion Matrix:
#
#      TN FP
#      FN TP
#
# where
#    - TN - actual negative, and predicted to be negative
#    - FN - actual negative, and predicted to be possitive
#    - FP - actual possitive, and predicted to be negative
#    - TN - actual possitive, and predicted to be possitive
#
# recall (negative predictor value) = TP / (TP + FN) how well model predict diabetes when patien actully has diabetes
#
#  precision (positive predictor value) = TP / (TP + FP) actually have diabetes when model said he would

# %% [markdown]
# ## Random forest

# %%
from sklearn.ensemble import RandomForestClassifier

# Create random forest object
rf_model = RandomForestClassifier(random_state=42, n_estimators=10)      

rf_model.fit(X_train, y_train.ravel())
# Out:
# RandomForestClassifier(n_estimators=10, random_state=42)

# %% [markdown]
# ### Predict Training Data

# %%
rf_predict_train = rf_model.predict(X_train)
# training metrics
print("Accuracy: {0:.4f}".format(metrics.accuracy_score(y_train, rf_predict_train)))
# Out:
# Accuracy: 0.9870

# %% [markdown]
# ### Predict Test Data

# %%
rf_predict_test = rf_model.predict(X_test)

# training metrics
print("Accuracy: {0:.4f}".format(metrics.accuracy_score(y_test, rf_predict_test)))
# Out:
# Accuracy: 0.7100

# %%
print(metrics.confusion_matrix(y_test, rf_predict_test) )
print("")
print("Classification Report")
print(metrics.classification_report(y_test, rf_predict_test))
# Out:
# [[121  30]
#  [ 37  43]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.77      0.80      0.78       151
#            1       0.59      0.54      0.56        80
#
#     accuracy                           0.71       231
#    macro avg       0.68      0.67      0.67       231
# weighted avg       0.70      0.71      0.71       231

# %% [markdown]
# Classical overfitting problem, when model does good prediction on training data, but does bed on testing

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# C - regularization hyperparam
lr_model =LogisticRegression(C=0.7, random_state=42, solver='liblinear', max_iter=10000)
lr_model.fit(X_train, y_train.ravel())
lr_predict_test = lr_model.predict(X_test)

# training metrics
print("Accuracy: {0:.4f}".format(metrics.accuracy_score(y_test, lr_predict_test)))
print(metrics.confusion_matrix(y_test, lr_predict_test) )
print("")
print("Classification Report")
print(metrics.classification_report(y_test, lr_predict_test))
# Out:
# Accuracy: 0.7446
# [[128  23]
#  [ 36  44]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.78      0.85      0.81       151
#            1       0.66      0.55      0.60        80
#
#     accuracy                           0.74       231
#    macro avg       0.72      0.70      0.71       231
# weighted avg       0.74      0.74      0.74       231

# %%
C_start = 0.1
C_end = 5
C_inc = 0.1

C_values, recall_scores = [], []

C_val = C_start
best_recall_score = 0
while (C_val < C_end):
    C_values.append(C_val)
    lr_model_loop = LogisticRegression(C=C_val, random_state=42, solver='liblinear')
    lr_model_loop.fit(X_train, y_train.ravel())
    lr_predict_loop_test = lr_model_loop.predict(X_test)
    recall_score = metrics.recall_score(y_test, lr_predict_loop_test)
    recall_scores.append(recall_score)
    if (recall_score > best_recall_score):
        best_recall_score = recall_score
        best_lr_predict_test = lr_predict_loop_test
        
    C_val = C_val + C_inc

best_score_C_val = C_values[recall_scores.index(best_recall_score)]
print("1st max value of {0:.3f} occured at C={1:.3f}".format(best_recall_score, best_score_C_val))

# %matplotlib inline 
plt.plot(C_values, recall_scores, "-")
plt.xlabel("C value")
plt.ylabel("recall score")
# Out:
# 1st max value of 0.613 occured at C=1.400
# Text(0, 0.5, 'recall score')

# %% [markdown]
# ### Logisitic regression with class_weight='balanced'

# %%
C_start = 0.1
C_end = 5
C_inc = 0.1

C_values, recall_scores = [], []

C_val = C_start
best_recall_score = 0
while (C_val < C_end):
    C_values.append(C_val)
    lr_model_loop = LogisticRegression(
        C=C_val, class_weight="balanced", random_state=42, solver='liblinear', max_iter=10000)
    lr_model_loop.fit(X_train, y_train.ravel())
    lr_predict_loop_test = lr_model_loop.predict(X_test)
    recall_score = metrics.recall_score(y_test, lr_predict_loop_test)
    recall_scores.append(recall_score)
    
    if (recall_score > best_recall_score):
        best_recall_score = recall_score
        best_lr_predict_test = lr_predict_loop_test
        
    C_val = C_val + C_inc

best_score_C_val = C_values[recall_scores.index(best_recall_score)]
print("1st max value of {0:.3f} occured at C={1:.3f}".format(best_recall_score, best_score_C_val))

# %matplotlib inline 
plt.plot(C_values, recall_scores, "-")
plt.xlabel("C value")
plt.ylabel("recall score")
# Out:
# 1st max value of 0.738 occured at C=0.300
# Text(0, 0.5, 'recall score')

# %%
from sklearn.linear_model import LogisticRegression
lr_model =LogisticRegression( class_weight="balanced", C=best_score_C_val, random_state=42, solver='liblinear')
lr_model.fit(X_train, y_train.ravel())
lr_predict_test = lr_model.predict(X_test)

# training metrics
print("Accuracy: {0:.4f}".format(metrics.accuracy_score(y_test, lr_predict_test)))
print(metrics.confusion_matrix(y_test, lr_predict_test) )
print("")
print("Classification Report")
print(metrics.classification_report(y_test, lr_predict_test))
print(metrics.recall_score(y_test, lr_predict_test))
# Out:
# Accuracy: 0.7143
# [[106  45]
#  [ 21  59]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.83      0.70      0.76       151
#            1       0.57      0.74      0.64        80
#
#     accuracy                           0.71       231
#    macro avg       0.70      0.72      0.70       231
# weighted avg       0.74      0.71      0.72       231
#
# 0.7375

# %% [markdown]
# ### K-fold validation data
#
# We split our training data into k-folds, and each time use some fold to validate our training
# ![image.png](attachment:image.png)
#
#
# for each fold deterimnd best hyperparameter value
# and then set model hyperparameter to avarage best

# %% [markdown]
# ### LogisticRegressionCV

# %%
from sklearn.linear_model import LogisticRegressionCV

# set number of jobs to -1 which uses all cores to parallelize
lr_cv_model = LogisticRegressionCV(
    n_jobs=-1,  # use all the cors on our systems
    random_state=42, 
    Cs=3,   # number of values, it will try, trying to find best reguralization param
    cv=10,  # number of folds 
    refit=False, 
    class_weight="balanced", 
    max_iter=500)  

lr_cv_model.fit(X_train, y_train.ravel())
# Out:
# LogisticRegressionCV(Cs=3, cv=10, max_iter=500, n_jobs=-1, random_state=42,
#                      refit=False)

# %% [markdown]
# ### Predict on Test data

# %%
lr_cv_predict_test = lr_cv_model.predict(X_test)

# training metrics
print("Accuracy: {0:.4f}".format(metrics.accuracy_score(y_test, lr_cv_predict_test)))
print(metrics.confusion_matrix(y_test, lr_cv_predict_test) )
print("")
print("Classification Report")
print(metrics.classification_report(y_test, lr_cv_predict_test))
# Out:
# Accuracy: 0.7489
# [[126  25]
#  [ 33  47]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.79      0.83      0.81       151
#            1       0.65      0.59      0.62        80
#
#     accuracy                           0.75       231
#    macro avg       0.72      0.71      0.72       231
# weighted avg       0.74      0.75      0.75       231

# %% [markdown]
# # Using your trained Model

# %% [markdown]
# ## Save trained model to file

# %%
from joblib import dump, load

dump(lr_cv_model, "./data/pima-trained-model.pkl")
# Out:
# ['./data/pima-trained-model.pkl']

# %% [markdown]
# ## Load trained model from file

# %%
lr_cv_model = load("./data/pima-trained-model.pkl")

# %% [markdown]
# ## Test Prediction on data
#
# Once the model is loaded we can use it to predict on some data.  In this case the data file contains a few rows from the original Pima CSV file.

# %%
# get data from truncated pima data file
df_predict = pd.read_csv("./data/pima-data-trunc.csv")
print(df_predict.shape)
# Out:
# (4, 10)

# %%
df_predict
# Out:
#    num_preg  glucose_conc  diastolic_bp  thickness  insulin   bmi  diab_pred  \
# 0         1            89            66         23       94  28.1      0.167
# 1         2           197            70         45      543  30.5      0.158
# 2         7           100             0          0        0  30.0      0.484
# 3         1           103            30         38       83  43.3      0.183
#
#    age    skin  diabetes
# 0   21  0.9062     False
# 1   53  1.7730      True
# 2   32  0.0000      True
# 3   33  1.4972     False

# %% [markdown]
# The truncated file contained 4 rows from the original CSV.
#
# Data is the same is in same format as the original CSV file's data.  Therefore, just like the original data, we need to transform it before we can make predictions on the data.
#
# Note: If the data had been previously "cleaned up" this would not be necessary.
#
# We do this by executed the same transformations as we did to the original data
#
# Start by dropping the "skin" which is the same as thickness, with different units.

# %%
del df_predict['skin']
df_predict
# Out:
#    num_preg  glucose_conc  diastolic_bp  thickness  insulin   bmi  diab_pred  \
# 0         1            89            66         23       94  28.1      0.167
# 1         2           197            70         45      543  30.5      0.158
# 2         7           100             0          0        0  30.0      0.484
# 3         1           103            30         38       83  43.3      0.183
#
#    age  diabetes
# 0   21     False
# 1   53      True
# 2   32      True
# 3   33     False

# %% [markdown]
# We need to drop the diabetes column since that is what we are predicting.
# Store data without the column with the prefix X as we did with the X_train and X_test to indicate that it contains only the columns we are prediction.

# %%
X_predict = df_predict
del X_predict['diabetes']

# %% [markdown]
# Data has 0 in places it should not.
#
# Just like test or test datasets we will use imputation to fix this.

# %%
#Impute with mean all 0 readings
from sklearn.impute import SimpleImputer
fill_0 = SimpleImputer(missing_values=0, strategy="mean") #, axis=0)
X_predict = fill_0.fit_transform(X_predict)

# %% [markdown]
# At this point our data is ready to be used for prediction.

# %% [markdown]
# ## Predict diabetes with the prediction data.  Returns 1 if True, 0 if false

# %%
lr_cv_model.predict(X_predict)
# Out:
# array([0, 1, 0, 0])
